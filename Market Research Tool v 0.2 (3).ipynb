# %% [markdown]
# # Market Research Tool
# #### Author: Jakub Supera, CTO Innovatie team | Requests or problems? j.supera@amsterdam.nl
#
# Except as represented in this agreement, all work product by Developer is provided ​“AS IS”. Other than as provided in this agreement, Developer makes no other warranties, express or implied, and hereby disclaims all implied warranties, including any warranty of merchantability and warranty of fitness for a particular purpose.

# %%
from tkinter import *
from tkinter import filedialog

# %matplotlib inline
root = Tk()
root.filename =  filedialog.askopenfilename(initialdir = "/",title = "Select file",filetypes = (("text files","*.docx"),("all files","*.*")))
print(root.filename)

# %%
import docx2txt

data1 = docx2txt.process(root.filename)
data = data1.replace('\n', '')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-382ad660b296> in <module>
#       1 import docx2txt
#       2
# ----> 3 data1 = docx2txt.process(root.filename)
#       4 data = data1.replace('\n', '')
#
# NameError: name 'root' is not defined

# %% [markdown]
# #### Notes from the meeting are uploaded in the background

# %%
from summa.summarizer import summarize
summary = summarize(data, language='dutch', words=50)

# %% [markdown]
# #### 50 words summary generated automatically

# %%
 print(summary)

# %% [markdown]
#  #### 3 keywords generated automatically

# %%
from textblob import TextBlob
from summa import keywords
keywords1 = keywords.keywords(summary,words=2,language='dutch')

nl_blob = TextBlob(keywords1)
nl_blob.detect_language()


keywords2 = nl_blob.translate(to='en')
keywords = str(keywords2)

# %%
print(keywords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a96950938a69> in <module>
#       1 from summa import keywords
# ----> 2 keywords1 = keywords.keywords(summary,words=2,language='dutch')
#       3
#       4 print(keywords1)
#       5
#
# NameError: name 'summary' is not defined

# %% [markdown]
#  #### To save your search results click PRINT and choose "Save as PDF"

# %% [markdown]
# <div>
# <img src="attachment:wired.jpg" width="100" align="left"/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:wired.jpg" width="200"/>
# </div>

# %%
try: 
    from googlesearch import search 
except ImportError:  
    print("No module named 'google' found") 
  
# to search 
query = "site: wired.co "+keywords
for j in search(query, tld="co.in", num=10, stop=10, pause=2,): 
    print(j)
# Out:
# https://app.dealroom.co/companies.startups
# https://app.dealroom.co/companies.startups/f/locations/anyof_Estonia/sub_industries/anyof_mobility
# https://app.dealroom.co/companies.startups/f/company_status/not_acquired/employees/anyof_51-200_201-500/geo/anyof_South%20West
# https://app.dealroom.co/companies/cobi
# https://app.dealroom.co/companies.startups/f/all_hq_regions/Amsterdam%20region
# https://map.wetechrotterdam.com/companies/flickbike
# https://www.iamsterdam.com/en/business/startupamsterdam/news/featured/how-to-make-the-most-of-the-amsterdam-startup-map
# https://startupmap.iamsterdam.com/companies/shoka
# https://sifted.eu/european-startups-top-rankings/
# https://finder.techleap.nl/companies/assemble_systems

# %% [markdown]
# <div>
# <img src="attachment:dealroom.png" width="100"/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:Sifted-1A.png" width="100" align="left"/>
# </div>

# %%
try: 
    from googlesearch import search 
except ImportError:  
    print("No module named 'google' found") 
  
# to search 
query = "site: sifted.eu "+keywords
for j in search(query, tld="co.in", num=10, stop=10, pause=2,): 
    print(j)
# Out:
# https://sift.com/
# https://sift.com/site-privacy
# https://www.sift.co.uk/
# http://www.conebi.eu/wp-content/uploads/2018/09/European-Bicyle-Industry-and-Market-Profile-2017-with-2016-data-update-September-2018.pdf
# https://ecf.com/sites/ecf.com/files/EUCS_full_doc_small_file.pdf
# http://ebma-brussels.eu/wp-content/uploads/2017/09/EBMA-Bike-Europe-Re-Industrialization-Bicycle-Valley-Articles.pdf
# http://www.unece.org/fileadmin/DAM/trans/doc/2017/wp6/ECE-TRANS-WP6-2017-Inf-5e__Cycling_.pdf
# http://www.europarl.europa.eu/RegData/etudes/BRIE/2016/583795/EPRS_BRI(2016)583795_EN.pdf
# https://eur-lex.europa.eu/legal-content/EN/TXT/HTML/?uri=OJ:C:2017:399:FULL&from=RO
# https://www.igus.gr/contentData/Product_Files/Download/pdf/EU_industry-solutions_web.pdf
# 'site: sifted.eubicycle'

# %% [markdown]
# <div>
# <img src="attachment:dealroom.png" width="100" align="left"/>
# </div>

# %%
try: 
    from googlesearch import search 
except ImportError:  
    print("No module named 'google' found") 
  
# to search 
query = "site: app.dealroom.co/companies.startups "+keywords
for j in search(query, tld="co.in", num=10, stop=10, pause=2,): 
    print(j)
# Out:
# https://app.dealroom.co/companies.startups/f/industries/sports
# https://app.dealroom.co/companies.startups
# https://app.dealroom.co/companies/pelofy
# https://app.dealroom.co/companies/cobi
# https://app.dealroom.co/companies.startups/f/locations/anyof_Estonia/sub_industries/anyof_mobility
# https://app.dealroom.co/companies/peloton_interactive
# https://securelink.net/wp-content/uploads/2019/04/WTR-TechReport2018-.pdf
# https://map.wetechrotterdam.com/companies/flickbike
# https://datacommons.technation.io/companies/bikemap
# https://startup-map.berlin/companies/cookee

# %% [markdown]
# ANGEL.CO

# %%
try: 
    from googlesearch import search 
except ImportError:  
    print("No module named 'google' found") 
  
# to search 
query = "site: angel.co "+keywords
for j in search(query, tld="co.in", num=10, stop=10, pause=2,): 
    print(j)
# Out:
# https://app.dealroom.co/companies.startups/f/industries/sports
# https://app.dealroom.co/companies.startups
# https://app.dealroom.co/companies/pelofy
# https://app.dealroom.co/companies/cobi
# https://app.dealroom.co/companies.startups/f/locations/anyof_Estonia/sub_industries/anyof_mobility
# https://app.dealroom.co/companies/peloton_interactive
# https://securelink.net/wp-content/uploads/2019/04/WTR-TechReport2018-.pdf
# https://map.wetechrotterdam.com/companies/flickbike
# https://datacommons.technation.io/companies/bikemap
# https://startup-map.berlin/companies/cookee

# %% [markdown]
# SILICON CANALS

# %%
try: 
    from googlesearch import search 
except ImportError:  
    print("No module named 'google' found") 
  
# to search 
query = "site: siliconcanals.com/ "+keywords
for j in search(query, tld="co.in", num=10, stop=10, pause=2,): 
    print(j)
# Out:
# https://app.dealroom.co/companies.startups/f/industries/sports
# https://app.dealroom.co/companies.startups
# https://app.dealroom.co/companies/pelofy
# https://app.dealroom.co/companies/cobi
# https://app.dealroom.co/companies.startups/f/locations/anyof_Estonia/sub_industries/anyof_mobility
# https://app.dealroom.co/companies/peloton_interactive
# https://securelink.net/wp-content/uploads/2019/04/WTR-TechReport2018-.pdf
# https://map.wetechrotterdam.com/companies/flickbike
# https://datacommons.technation.io/companies/bikemap
# https://startup-map.berlin/companies/cookee

# %% [markdown]
# SPROUT.NL

# %%
try: 
    from googlesearch import search 
except ImportError:  
    print("No module named 'google' found") 
  
# to search 
query = "site: sprout.nl/ "+keywords1
for j in search(query, tld="co.in", num=10, stop=10, pause=2,): 
    print(j)
# Out:
# https://app.dealroom.co/companies.startups/f/industries/sports
# https://app.dealroom.co/companies.startups
# https://app.dealroom.co/companies/pelofy
# https://app.dealroom.co/companies/cobi
# https://app.dealroom.co/companies.startups/f/locations/anyof_Estonia/sub_industries/anyof_mobility
# https://app.dealroom.co/companies/peloton_interactive
# https://securelink.net/wp-content/uploads/2019/04/WTR-TechReport2018-.pdf
# https://map.wetechrotterdam.com/companies/flickbike
# https://datacommons.technation.io/companies/bikemap
# https://startup-map.berlin/companies/cookee
